# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # **My Jupyter Notebook on IBM Watson Studio**

# %% [markdown]
# __Jamie__
#
# I am curently a student

# %% [markdown]
# _I am interested in data science because I like statistics_

# %% [markdown]
# ### The following code calculates 1+1

# %%
1+1
# Out:
# 2

# %% [markdown]
# ![u=4108453355,850527550&fm=253&fmt=auto&app=138&f=JPEG.jpeg](attachment:d23a3a59-6534-45c6-92e1-d10fc0b2084e.jpeg)
# *** this is a picture
# <!DOCTYPE html>
# <html>
# <style>
# body {
#   font-size: 20px;
# }
# </style>
# <body>
#
# <span style='font-size:100px;'>&#9632;</span>
# <p>I will display &#9632;</p>
# <p>I will display &#9632;</p>
